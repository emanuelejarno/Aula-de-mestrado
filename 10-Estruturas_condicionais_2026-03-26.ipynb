# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Dados as operações abaixo, em Python, qual o resultado da operação lógica:
# p and q and r and s and t?
# <br>
# <br>Imprima os objetos e o resultado usando uma estrutura condicional.
#
# <br>p = 2.0 + 3.0 / 5.0 == 10
# <br>q = (p + 10.2) - 5.0 * 2.0 <= 2.9
# <br>r = 10 <= p / q + 33.8 < 100
# <br>s = 5 != p / (q + r)
# <br>t = 33 == s * 2

# %%
p = 2.0 + 3.0 / 5.0 == 10
q = (p + 10.2) - 5.0 * 2.0 <= 2.9
r = 10 <= p / q + 33.8 < 100
s = 5 != p / (q + r)
t = 33 == s * 2

resultado = p and q and r and s and t

print(p, q, r, s, t)

if resultado:
    print("True")
else:
    print("False")
# Out:
# False True True True False
# False

# %% [markdown]
# ## Instancie um objeto da classe array numpy, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Criei um array com valores aleatórios seguindo uma distribuição normal (média 10 e desvio 3). Depois disso, selecionei apenas os números maiores que 10 usando uma condição e contei quantos deles existem.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# R.:  <img src="./img/fluxograma ex 3.png" width="400" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

arr = np.random.normal(loc=10, scale=3, size=5)

valores_superiores = arr[arr > 10]
quantidade = len(valores_superiores)

print(arr)
print(quantidade)
print(valores_superiores)
# Out:
# [ 9.6879567  11.98217041 10.98323462  4.39326995  3.87659304]
# 2
# [11.98217041 10.98323462]

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %%
Sim, é possível, porque o método não depende do valor 10 especificamente

# %% [markdown]
# ## 06 – Instancie um objeto da classe lista com os valores obtidos no exercício 02.
#
# O valor 10.453444246931676 está presente?

# %%
lista = list(arr)

presente = 10.453444246931676 in lista

print(lista)
print(presente)
# Out:
# [np.float64(9.687956701955214), np.float64(11.982170412666756), np.float64(10.983234622327556), np.float64(4.393269946115241), np.float64(3.8765930392410493)]
# False

# %% [markdown]
# ## No exercício 7 da aula 6, foi instanciado um objeto da classe DataFrame. Exporte (usando nome_data_frame.to_csv(‘nome_arquivo.csv’)) para .csv estes dados e os importe (com pd.read_csv(‘nome_arquivo.csv’) aqui. Edite o objeto para que os index sejam os nomes dos genes e para que as colunas sejam facilmente identificadas. Usando o número de caracteres do primeiro gene, quero saber a informação gênica. Caso o nome tenha entre 2 e 4 caracteres inclusive, posso saber as informações do gene? Porém, caso tenha menos de 2 caracteres, posso saber todos os valores nas instâncias onde os números de caracteres dos nomes são superiores a 4? Ainda, caso tenha mais de 4 caracteres, apenas me informe quem é superior.

# %% [markdown]
# ## 07 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: A lógica usa o tamanho do nome do primeiro gene para decidir o que mostrar. Dependendo desse tamanho, o código escolhe entre exibir os dados do próprio gene, filtrar genes com nomes maiores que 4 caracteres ou apenas listar quais atendem a essa condição.

# %% [markdown]
# ## 08 – Desenhe o fluxograma da resposta:

# %% [markdown]
# R.:  <img src="./img/fluxograma ex 8.png" width="400" />

# %% [markdown]
# ## 09 – Escreva o programa em Python:

# %%
import pandas as pd

df = pd.read_csv("dataframel6e7.csv", index_col="Unnamed: 0")

df.index.name = "gene"
df.columns = ["num_caract","primeiros_2_caract","quant_a","tem_hu"]

primeiro_gene = df.index[0]
n = len(primeiro_gene)

if 2 <= n <= 4:
    print(df.loc[primeiro_gene])
elif n < 2:
    print(df[df.index.str.len() > 4])
else:
    print(df.index[df.index.str.len() > 4])
# Out:
# num_caract                4
# primeiros_2_caract       ES
# quant_a                   0
# tem_hu                False
# Name: ESR1, dtype: object

# %% [markdown]
# ## 10 – Caso a DataFrame contenha 10 milhões de entradas, este racional utilizado poderia responder as mesmas perguntas? Porque?

# %% [markdown]
# R.: Sim, dá pra usar a mesma lógica mesmo com muitos dados, porque ela não muda. Mas com 10 milhões de registros, pode ficar mais pesado e demorado, então seria preciso otimizar para rodar bem.
